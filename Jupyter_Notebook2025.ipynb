# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
# Ejemplos de Expresiones Aritméticas
## Introducción  

En este cuaderno exploraremos ejemplos de expresiones aritméticas en Python.  
Realizaremos operaciones matemáticas básicas como suma, resta, multiplicación, división y potencias,  
demostrando su implementación en código.  
## Lenguajes de Programación en Ciencia de Datos  

Algunos de los principales lenguajes utilizados en ciencia de datos son:  

- **Python**: Popular por su simplicidad y sus potentes bibliotecas como NumPy, pandas y scikit-learn.  
- **R**: Preferido en análisis estadístico y visualización de datos.  
- **SQL**: Usado para manipulación y consulta de bases de datos.  
- **Julia**: Optimizado para cálculos numéricos de alto rendimiento.  
- **Scala**: Utilizado en entornos de big data con Apache Spark.  

## Bibliotecas de Ciencia de Datos  

Algunas bibliotecas populares en ciencia de datos incluyen:  

- **NumPy**: Soporte para arreglos y operaciones matemáticas.  
- **pandas**: Manipulación y análisis de datos en estructuras como DataFrames.  
- **Matplotlib**: Visualización de datos mediante gráficos.  
- **Seaborn**: Extensión de Matplotlib para gráficos más atractivos.  
- **scikit-learn**: Algoritmos de aprendizaje automático.  
- **TensorFlow**: Desarrollo de modelos de aprendizaje profundo.  
- **PyTorch**: Otra popular biblioteca para redes neuronales.  

## Herramientas de Ciencia de Datos  

| Herramienta         | Descripción                                      |
|---------------------|------------------------------------------------|
| Jupyter Notebook   | Entorno interactivo para ejecutar código.       |
| RStudio           | Entorno de desarrollo para R.                    |
| Apache Spark      | Procesamiento de big data a gran escala.         |
| Tableau          | Visualización y análisis de datos interactivos.   |
| Power BI         | Análisis y creación de dashboards.                |
| Google Colab     | Ejecución de Jupyter Notebooks en la nube.        |

## Ejemplos de Expresiones Aritméticas  

A continuación, se presentan algunas expresiones aritméticas en Python:  

- **Suma**: `5 + 3 = 8`  
- **Resta**: `10 - 4 = 6`  
- **Multiplicación**: `6 * 7 = 42`  
- **División**: `20 / 4 = 5.0`  
- **Potencia**: `2 ** 3 = 8`  
- **Módulo**: `10 % 3 = 1`  

# Multiplicación y suma
num1 = 5
num2 = 3
multiplicacion = num1 * num2
suma = num1 + num2

print("Multiplicación:", multiplicacion)
print("Suma:", suma)

# Conversión de minutos a horas
minutos = 150
horas = minutos / 60
print(f"{minutos} minutos equivalen a {horas} horas.")

# Lista de objetivos del cuaderno
objetivos = [
    "Aprender sobre expresiones aritméticas en Python.",
    "Practicar operaciones matemáticas básicas.",
    "Familiarizarse con Jupyter Notebook y Markdown."
]

for i, objetivo in enumerate(objetivos, 1):
    print(f"{i}. {objetivo}")

## Autor  

Este cuaderno fue creado por: **Isadora Silva Meneses**

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
